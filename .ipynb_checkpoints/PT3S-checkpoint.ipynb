# %% [markdown]
# # PT3S
# Use SIR 3S Modeldata and SIR 3S Results in pure Python.
#
# With pandas, matplotlib and others.
#
# For documentation, test, verification, analysis, reporting, prototyping, play.

# %% [markdown]
# ## Install
# Python 3.5.2 (Anaconda 4.2.0 (64-bit))

# %%
# !pip uninstall --yes PT3S
# !pip install PT3S

# %% [markdown]
# ## PT3S Imports

# %%
# %pwd

# %%
# currentWorkingDirectory should be after Kernel (Re-)Start the notebookDir 
# in this case PT3SSourcecodeDir (the Dir with PT3S' __init__.py and PT3S.ipynb (this notebook))

# PT3S-Imports:
# only if
# !pip install -e .
# is active 
# then _before the PT3S Imports the currentWorkingDirectory _has to be changed to .. PT3SSourcecodeDir  
# %cd -q ..
from PT3S import Mx,Xm,Rm
# %cd -q PT3S 
# if !pip install -e . is active the cd-Change has no effect

# %% [markdown]
# # Imports

# %%
import unittest
import doctest

# %% [markdown]
# # Test Mx

# %%
# run the tests ...
unittest.TextTestRunner().run(doctest.DocTestSuite(Mx))

# %% [markdown]
# # Test Xm

# %%
# run the tests ...
unittest.TextTestRunner().run(doctest.DocTestSuite(Xm))

# %% [markdown]
# # Test Rm

# %%
# run the tests ...
unittest.TextTestRunner().run(doctest.DocTestSuite(Rm))

# %%
# ---
# Imports
# ---
import logging
logger = logging.getLogger('PT3S')  
import os
import pandas as pd
import matplotlib.pyplot as plt
path = os.path.dirname('.')

# ---
# LocalHeatingNetwork
# ---
xmlFile=os.path.join(path,'testdata\LocalHeatingNetwork.XML')
xm=Xm.Xm(xmlFile=xmlFile)
mx1File=os.path.join(path,'testdata\WDLocalHeatingNetwork\B1\V0\BZ1\M-1-0-1.MX1')
mx=Mx.Mx(mx1File=mx1File,NoH5Read=True,NoMxsRead=True)
mx.setResultsToMxsFile(NewH5Vec=True)
rm=Rm.Rm(xm=xm,mx=mx)

# %%
xm.dataFrames['vROHR'].columns

# %%
mx.mx1Df[(mx.mx1Df['isVectorChannelMx2']) & (mx.mx1Df['Sir3sID'].str.startswith('ROHR')) ]

# %%
# Prozentdarstellung - keine Klassen
plt.close('all')
fig=plt.figure()
x=rm.pltNetDHUS(timeDeltaToT= pd.to_timedelta('30 seconds')                   
                
               # ALLG
               ,pFWVBMeasureInRefPerc=True 
               ,pFWVBMeasure3Classes=False 
               
               ,pFWVBMeasureCBFixedLimits=False                
                
               # FWVB
               ,pFWVBMeasure='FWVB~*~*~*~W'
               ,pFWVBAttribute='W0LFK'
                                                                                             
               ,pFWVBAttributeRefSize=50
                
               ,pFWVBMeasureColorMap=plt.cm.autumn 
               ,pFWVBMeasureAlpha=0.9 
               ,pFWVBMeasureClip=False                  

               ,limitTopColor='palegreen'
               ,limitTopAlpha=0.9 
               ,limitTopClip=False            
               ,limitTopText='Top'                 
               
               ,limitBottomColor='violet' 
               ,limitBottomAlpha=0.9 
               ,limitBottomClip=False    
               ,limitBottomText='Bottom' 
                
               ,limitMiddleColorMap=plt.cm.autumn 
               ,limitMiddleAlpha=0.9 
               ,limitMiddleClip=False    
               ,limitMiddleText='Middle'                
  
                # CB                
                ,CBFraction=.05  
                ,CBHpad=.0275   
                ,CBLabelPad=0
                ,CBAspect=10.
                ,CBShrink=1.
                ,CBAnchorHorizontal=0.
                ,CBAnchorVertical=0.

                # ROHR
                ,pROHRMeasure='ROHR~*~*~*~QMAV'
                ,pROHRAttribute='DI'              
                
                ,pROHRClip=False
                ,pROHRAttributeLs='-' 
                ,pROHRMeasureMarker='.'

                ,pROHRAttributeColorMap=plt.cm.binary    
                ,pROHRAttríbuteColorMapUsageStart=1./3
                ,pROHRAttributeRefSize=3.               

                ,pROHRMeasureColorMap=plt.cm.cool    
                ,pROHRMeasureColorMapUsageStart=0.               
                ,pROHRMeasureRefSize=12.                        
                                                          
               )
plt.show()

# %%
# herkömmliche Darstellung
plt.close('all')
fig=plt.figure()
x=rm.pltNetDHUS(timeDeltaToT= pd.to_timedelta('30 seconds')                   
                
               # ALLG
               ,pFWVBMeasureInRefPerc=False
               ,pFWVBMeasure3Classes=False 
               
               ,pFWVBMeasureCBFixedLimits=False                
                
               # FWVB
               ,pFWVBMeasure='FWVB~*~*~*~W'
               ,pFWVBAttribute='W0LFK'
                                                                                             
               ,pFWVBAttributeRefSize=50
                
               ,pFWVBMeasureColorMap=plt.cm.autumn 
               ,pFWVBMeasureAlpha=0.9 
               ,pFWVBMeasureClip=False                  

               ,limitTopColor='palegreen'
               ,limitTopAlpha=0.9 
               ,limitTopClip=False            
               ,limitTopText='Top'                 
               
               ,limitBottomColor='violet' 
               ,limitBottomAlpha=0.9 
               ,limitBottomClip=False    
               ,limitBottomText='Bottom' 
                
               ,limitMiddleColorMap=plt.cm.autumn 
               ,limitMiddleAlpha=0.9 
               ,limitMiddleClip=False    
               ,limitMiddleText='Middle'                
  
                # CB                
                ,CBFraction=.05  
                ,CBHpad=.0275   
                ,CBLabelPad=0
                ,CBAspect=10.
                ,CBShrink=1.
                ,CBAnchorHorizontal=0.
                ,CBAnchorVertical=0.

                # ROHR
                ,pROHRMeasure='ROHR~*~*~*~QMAV'
                ,pROHRAttribute='DI'              
                
                ,pROHRClip=False
                ,pROHRAttributeLs='-' 
                ,pROHRMeasureMarker='.'

                ,pROHRAttributeColorMap=plt.cm.binary    
                ,pROHRAttríbuteColorMapUsageStart=1./3
                ,pROHRAttributeRefSize=3.               

                ,pROHRMeasureColorMap=plt.cm.cool    
                ,pROHRMeasureColorMapUsageStart=0.               
                ,pROHRMeasureRefSize=12.                        
                                                          
               )
plt.show()

# %%
plt.close('all')
fig=plt.figure(linewidth=1.)
pFWVB=rm.pltNetDHUS(
               # TIME
               timeDeltaToT= pd.to_timedelta('30 seconds')                   
                
               # ALLG
               ,pFWVBMeasureInRefPerc=True
               ,pFWVBMeasure3Classes=True 
               
               ,pFWVBMeasureCBFixedLimits=True         
               ,pFWVBMeasureCBFixedLimitLow=.659
               ,pFWVBMeasureCBFixedLimitHigh=.809
                
               # FWVB
               ,pFWVBMeasure='FWVB~*~*~*~W'
               ,pFWVBAttribute='W0LFK'
               ,pFWVBAttributeAsc=False    
               ,pFWVBGCategory=['BLNZ1u5u7'] # ['Süd','Nord','Innenstadt','Nord PWS','NordOst BHW','Ost HWV','Ost PWF/PSE','Nord Rest'] # NAMEn von WBLZ
               ,pFWVBGCategoryXStart=.1
               ,pFWVBGCategoryYStart=.9
               ,pFWVBGCategoryYSpace=-.1               
                                                                                             
               ,pFWVBAttributeRefSize=50
                
               ,pFWVBMeasureColorMap=plt.cm.autumn 
               ,pFWVBMeasureAlpha=0.9 
               ,pFWVBMeasureClip=False                  

               ,limitTopColor='palegreen'
               ,limitTopAlpha=0.9 
               ,limitTopClip=False            
               ,limitTopText='Top'                 
               
               ,limitBottomColor='violet' 
               ,limitBottomAlpha=0.9 
               ,limitBottomClip=False    
               ,limitBottomText='Bottom' 
                
               ,limitMiddleColorMap=plt.cm.autumn 
               ,limitMiddleAlpha=0.9 
               ,limitMiddleClip=False    
               ,limitMiddleText='Middle'                
  
                # CB                
                ,CBFraction=.05  
                ,CBHpad=.0275   
                ,CBLabelPad=0
                ,CBTicklabelsHPad=-3.
                ,CBAspect=10.
                ,CBShrink=1.
                ,CBAnchorHorizontal=0.
                ,CBAnchorVertical=0.

                # ROHR
                ,pROHRMeasure='ROHR~*~*~*~QMAV'
                ,pROHRMeasureAbs=True 
                ,pROHRAttribute='DI'    
                ,pROHRAttributeAsc=False                
                
                ,pROHRClip=False
                ,pROHRAttributeLs='-' 
                ,pROHRMeasureMarker='.'

                ,pROHRAttributeColorMap=plt.cm.binary    
                ,pROHRAttríbuteColorMapUsageStart=1./3
                ,pROHRAttributeRefSize=3.               

                ,pROHRMeasureColorMap=plt.cm.cool    
                ,pROHRMeasureColorMapUsageStart=0.               
                ,pROHRMeasureRefSize=12.     

                # CB Legend (3Classes)
                ,CBLe3cTopVPad=1+1*1/4            
                ,CBLe3cMiddleVPad=.5                                                                         
                ,CBLe3cBottomVPad=0-1*1/4                  
                
                # TB      
                ,TBVSpace=0.2 
                ,TBHSpace=1.
                            
                # FIG                   
                ,pltTitle='pltNetDHUS: Klassendarstellung - Prozent '             
                ,figFrameon=True                 
                ,figEdgecolor='black' 
                ,figFacecolor='white'                 
               )
plt.show()

# %%
vNRCV_Mx1=xm.dataFrames['vNRCV_Mx1']
vNRCV_Mx1.columns
# Out:
# Index(['Sir3sID', 'cRefLfdNr', 'CONT', 'CONT_ID', 'CONT_LFDNR', 'DPGR',
#        'OBJTYPE', 'fkOBJTYPE', 'ATTRTYPE', 'pk_ROWS', 'tk_ROWS', 'pk', 'tk',
#        'pXYLB'],
#       dtype='object')

# %%
vNRCV_Mx1_g=vNRCV_Mx1.groupby(['Sir3sID']).size()

# %%
vNRCV_Mx1_Sir3sIDs=pd.DataFrame(vNRCV_Mx1_g.index)

# %%
vNRCV_Mx1_Sir3sIDs
# Out:
#                                          Sir3sID
# 0              FWES~R3~V-1~5638756766880678918~W
# 1       KNOT~PKON-Knoten~~5397990465339071638~QM
# 2               KNOT~R-L~~5356267303828212700~PH
# 3                 KNOT~R3~~5219230031772497417~T
# 4                KNOT~V-1~~5049461676240771430~T
# 5            KNOT~V-K007~~5741235692335544560~DP
# 6               KNOT~V-L~~5736262931552588702~PH
# 7              PUMP~R-1~R2~5481331875203087055~N
# 8            VENT~V-1~V-L~4678923650983295610~QM
# 9        WBLZ~BLNZ1u5u7~~4694700216019268978~WVB
# 10    WBLZ~WärmeblnzGes~~5262603207038486299~WES
# 11  WBLZ~WärmeblnzGes~~5262603207038486299~WSPEI
# 12    WBLZ~WärmeblnzGes~~5262603207038486299~WVB
# 13  WBLZ~WärmeblnzGes~~5262603207038486299~WVERL

# %%
vKNOT=xm.dataFrames['vKNOT']
#vFWVB=pFWVB #xm.dataFrames['vFWVB']
vWBLZ=xm.dataFrames['vWBLZ']
vWBLZ_vKNOT=pd.merge(vWBLZ,vKNOT,left_on='OBJID',right_on='pk')
vWBLZ_vKNOT_pFWVB=pd.merge(vWBLZ_vKNOT,pFWVB,left_on='NAME_y',right_on='NAME_i')
vWBLZ_vKNOT_pFWVB.columns
# Out:
# Index(['AKTIV', 'BESCHREIBUNG_x', 'IDIM', 'NAME_x', 'OBJID', 'OBJTYPE', 'pk_x',
#        'NAME_y', 'BESCHREIBUNG_y', 'IDREFERENZ_x', 'CONT_x', 'CONT_ID_x',
#        'CONT_LFDNR_x', 'CONT_VKNO', 'KTYP', 'LFAKT', 'QM_EIN', 'QVAR_NAME',
#        'QM', 'QM_min', 'QM_max', 'KVR', 'TE', 'TM', 'XKOR', 'YKOR', 'ZKOR',
#        'pk_y', 'tk_x', 'pXCor', 'pYCor', 'BESCHREIBUNG', 'IDREFERENZ_y', 'W0',
#        'LFK', 'W0LFK', 'TVL0', 'TRS0', 'LFKT', 'W', 'W_min', 'W_max', 'INDTR',
#        'TRSK', 'VTYP', 'DPHAUS', 'IMBG', 'IRFV', 'pk', 'tk_y', 'NAME_i',
#        'KVR_i', 'TM_i', 'XKOR_i', 'YKOR_i', 'ZKOR_i', 'pXCor_i', 'pYCor_i',
#        'NAME_k', 'KVR_k', 'TM_k', 'XKOR_k', 'YKOR_k', 'ZKOR_k', 'pXCor_k',
#        'pYCor_k', 'CONT_y', 'CONT_ID_y', 'CONT_LFDNR_y', 'WBLZ', 'Measure',
#        'MCategory', 'GCategory'],
#       dtype='object')

# %%
vWBLZ_vKNOT_pFWVB=vWBLZ_vKNOT_pFWVB[['NAME_x','NAME_i','pk_x','WBLZ', 'Measure','MCategory', 'GCategory']]
vWBLZ_vKNOT_pFWVB.rename(columns={'NAME_x':'NAME','pk_x':'pkWBLZ'},inplace=True)
vWBLZ_vKNOT_pFWVB
# Out:
#         NAME  NAME_i               pkWBLZ                         WBLZ  \
# 0      BLNZ1  V-K002  5579937562601803472  [BLNZ1, BLNZ1u5, BLNZ1u5u7]
# 1    BLNZ1u5  V-K002  5187647097142898375  [BLNZ1, BLNZ1u5, BLNZ1u5u7]
# 2  BLNZ1u5u7  V-K002  4694700216019268978  [BLNZ1, BLNZ1u5, BLNZ1u5u7]
# 3      BLNZ5  V-K005  5581152085151655438  [BLNZ1u5, BLNZ1u5u7, BLNZ5]
# 4    BLNZ1u5  V-K005  5187647097142898375  [BLNZ1u5, BLNZ1u5u7, BLNZ5]
# 5  BLNZ1u5u7  V-K005  4694700216019268978  [BLNZ1u5, BLNZ1u5u7, BLNZ5]
# 6  BLNZ1u5u7  V-K007  4694700216019268978                  [BLNZ1u5u7]
#
#     Measure MCategory  GCategory
# 0  0.809706       Top  BLNZ1u5u7
# 1  0.809706       Top  BLNZ1u5u7
# 2  0.809706       Top  BLNZ1u5u7
# 3  0.660432    Middle  BLNZ1u5u7
# 4  0.660432    Middle  BLNZ1u5u7
# 5  0.660432    Middle  BLNZ1u5u7
# 6  0.655515    Bottom  BLNZ1u5u7

# %%
vWBLZ_vKNOT_pFWVB_vNRCV_Mx1=pd.merge(vWBLZ_vKNOT_pFWVB,vNRCV_Mx1,left_on='pkWBLZ',right_on='fkOBJTYPE',how='left')
#vWBLZ_vKNOT_pFWVB_vNRCV_Mx1=vWBLZ_vKNOT_pFWVB_vNRCV_Mx1.drop_duplicates()

# %%
vWBLZ_vKNOT_pFWVB_vNRCV_Mx1=vWBLZ_vKNOT_pFWVB_vNRCV_Mx1[['NAME','NAME_i','WBLZ','Sir3sID', 'Measure','MCategory', 'GCategory']]#.drop_duplicates()

# %%
vWBLZ_vKNOT_pFWVB_vNRCV_Mx1
# Out:
#         NAME  NAME_i                         WBLZ  \
# 0      BLNZ1  V-K002  [BLNZ1, BLNZ1u5, BLNZ1u5u7]
# 1    BLNZ1u5  V-K002  [BLNZ1, BLNZ1u5, BLNZ1u5u7]
# 2  BLNZ1u5u7  V-K002  [BLNZ1, BLNZ1u5, BLNZ1u5u7]
# 3      BLNZ5  V-K005  [BLNZ1u5, BLNZ1u5u7, BLNZ5]
# 4    BLNZ1u5  V-K005  [BLNZ1u5, BLNZ1u5u7, BLNZ5]
# 5  BLNZ1u5u7  V-K005  [BLNZ1u5, BLNZ1u5u7, BLNZ5]
# 6  BLNZ1u5u7  V-K007                  [BLNZ1u5u7]
#
#                                    Sir3sID   Measure MCategory  GCategory
# 0                                      NaN  0.809706       Top  BLNZ1u5u7
# 1                                      NaN  0.809706       Top  BLNZ1u5u7
# 2  WBLZ~BLNZ1u5u7~~4694700216019268978~WVB  0.809706       Top  BLNZ1u5u7
# 3                                      NaN  0.660432    Middle  BLNZ1u5u7
# 4                                      NaN  0.660432    Middle  BLNZ1u5u7
# 5  WBLZ~BLNZ1u5u7~~4694700216019268978~WVB  0.660432    Middle  BLNZ1u5u7
# 6  WBLZ~BLNZ1u5u7~~4694700216019268978~WVB  0.655515    Bottom  BLNZ1u5u7

# %%
vWBLZ_vKNOT_pFWVB_vNRCV_Mx1['Sir3sID']=vWBLZ_vKNOT_pFWVB_vNRCV_Mx1['Sir3sID'].fillna(value='')

# %%
df=vWBLZ_vKNOT_pFWVB_vNRCV_Mx1.groupby(['NAME','MCategory','Sir3sID']).size()#.sort_values(['NAME','MCategory'])

# %%
df
# Out:
# NAME       MCategory  Sir3sID
# BLNZ1      Top                                                   1
# BLNZ1u5    Middle                                                1
#            Top                                                   1
# BLNZ1u5u7  Bottom     WBLZ~BLNZ1u5u7~~4694700216019268978~WVB    1
#            Middle     WBLZ~BLNZ1u5u7~~4694700216019268978~WVB    1
#            Top        WBLZ~BLNZ1u5u7~~4694700216019268978~WVB    1
# BLNZ5      Middle                                                1
# dtype: int64

# %%
df.loc['BLNZ1']['Top']
# Out:
# 1

# %%
type(df)
df.index
# Out:
# MultiIndex(levels=[['BLNZ1', 'BLNZ1u5', 'BLNZ1u5u7', 'BLNZ5'], ['Bottom', 'Middle', 'Top']],
#            labels=[[0, 1, 1, 2, 2, 2, 3], [2, 1, 2, 0, 1, 2, 1]],
#            names=['NAME', 'MCategory'])

# %%
s=pFWVB.groupby(['GCategory']).size() #count()
s
#df=pd.DataFrame(s)
#df.columns
s.loc['BLNZ1u5u7']
# Out:
# 3

# %%
pFWVB[pFWVB['Measure']<1].groupby(['GCategory']).size() #count()
# Out:
# GCategory
#              2
# BLNZ1u5u7    3
# dtype: int64

# %%
import numpy as np

pFWVB.groupby(['GCategory']).agg({'Measure': [np.size, np.mean]})


pFWVB_UV=pFWVB[pFWVB['Measure']<1]

pFWVB_UV.groupby(['GCategory']).agg({'Measure': [np.size, np.mean]}).reindex()

# %%
vKNOT=xm.dataFrames['vKNOT']
vFWVB=xm.dataFrames['vFWVB']
vNRCV_Mx1=xm.dataFrames['vNRCV_Mx1']
vWBLZ=xm.dataFrames['vWBLZ']
df=pd.merge(vNRCV_Mx1,vWBLZ,left_on='fkOBJTYPE',right_on='pk')
df=df[['Sir3sID','NAME','IDIM']].drop_duplicates()

#vWBLZ
vWBLZ
#df
#vFWVB.columns

#vKNOT_WBLZ=pd.merge(vWBLZ,vKNOT,left_on='OBJID',right_on='pk')
#vKNOT_WBLZ_FWVB=pd.merge(vKNOT_WBLZ,vFWVB,left_on='NAME_y',right_on='NAME_i')
#vKNOT_WBLZ_FWVB.columns
#vKNOT_WBLZ_FWVB=vKNOT_WBLZ_FWVB[['NAME_x','NAME_y','pk']].groupby('')
#vKNOT_WBLZ_FWVB

#pFWVB.columns
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\Wolters\Anaconda3\lib\site-packages\pandas\indexes\base.py in get_loc(self, key, method, tolerance)
#    1944             try:
# -> 1945                 return self._engine.get_loc(key)
#    1946             except KeyError:
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4154)()
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4018)()
#
# pandas\hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:12368)()
#
# pandas\hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:12322)()
#
# KeyError: ''
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-f2f36e282134> in <module>()
#      14 vKNOT_WBLZ_FWVB=pd.merge(vKNOT_WBLZ,vFWVB,left_on='NAME_y',right_on='NAME_i')
#      15 vKNOT_WBLZ_FWVB.columns
# ---> 16 vKNOT_WBLZ_FWVB=vKNOT_WBLZ_FWVB[['NAME_x','NAME_y','pk']].groupby('')
#      17 vKNOT_WBLZ_FWVB
#      18
#
# C:\Users\Wolters\Anaconda3\lib\site-packages\pandas\core\generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, **kwargs)
#    3776         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    3777                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 3778                        **kwargs)
#    3779
#    3780     def asfreq(self, freq, method=None, how=None, normalize=False):
#
# C:\Users\Wolters\Anaconda3\lib\site-packages\pandas\core\groupby.py in groupby(obj, by, **kwds)
#    1425         raise TypeError('invalid type: %s' % type(obj))
#    1426
# -> 1427     return klass(obj, by, **kwds)
#    1428
#    1429
#
# C:\Users\Wolters\Anaconda3\lib\site-packages\pandas\core\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, **kwargs)
#     352                                                     level=level,
#     353                                                     sort=sort,
# --> 354                                                     mutated=self.mutated)
#     355
#     356         self.obj = obj
#
# C:\Users\Wolters\Anaconda3\lib\site-packages\pandas\core\groupby.py in _get_grouper(obj, key, axis, level, sort, mutated)
#    2381
#    2382         elif is_in_axis(gpr):  # df.groupby('name')
# -> 2383             in_axis, name, gpr = True, gpr, obj[gpr]
#    2384             exclusions.append(name)
#    2385
#
# C:\Users\Wolters\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    1995             return self._getitem_multilevel(key)
#    1996         else:
# -> 1997             return self._getitem_column(key)
#    1998
#    1999     def _getitem_column(self, key):
#
# C:\Users\Wolters\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2002         # get column
#    2003         if self.columns.is_unique:
# -> 2004             return self._get_item_cache(key)
#    2005
#    2006         # duplicate columns & possible reduce dimensionality
#
# C:\Users\Wolters\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    1348         res = cache.get(item)
#    1349         if res is None:
# -> 1350             values = self._data.get(item)
#    1351             res = self._box_item_values(item, values)
#    1352             cache[item] = res
#
# C:\Users\Wolters\Anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    3288
#    3289             if not isnull(item):
# -> 3290                 loc = self.items.get_loc(item)
#    3291             else:
#    3292                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# C:\Users\Wolters\Anaconda3\lib\site-packages\pandas\indexes\base.py in get_loc(self, key, method, tolerance)
#    1945                 return self._engine.get_loc(key)
#    1946             except KeyError:
# -> 1947                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    1948
#    1949         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4154)()
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4018)()
#
# pandas\hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:12368)()
#
# pandas\hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:12322)()
#
# KeyError: ''

# %% [markdown]
# # Deploy
#
# python setup.py clean sdist bdist_wheel
#
# pip install twine
#
# twine upload dist/*

# %% [markdown]
# # Develop

# %%
# !pip install -e .

# %% [markdown]
# due to ...\Lib\site-packages\PT3S.egg-link
#
# import PT3S
#
# will work (if PythonShell is executed .. PT3SSourcecodeDir)
#
# and point to _local PT3SSourcecodeDir

# %% [markdown]
# Repository: https://github.com/aw3s/PT3S.git
