# %% [markdown]
# # PT3S
# Use SIR 3S Modeldata and SIR 3S Results in pure Python.
#
# With pandas, matplotlib and others.
#
# For documentation, test, verification, analysis, reporting, prototyping, play.

# %% [markdown]
# ## Install
# Python 3.5.2 (Anaconda 4.2.0 (64-bit))

# %%
# !pip uninstall --yes PT3S
# !pip install PT3S

# %% [markdown]
# ## PT3S Imports

# %%
# %pwd

# %%
# currentWorkingDirectory should be after Kernel (Re-)Start the notebookDir 
# in this case PT3SSourcecodeDir (the Dir with PT3S' __init__.py and PT3S.ipynb (this notebook))

# PT3S-Imports:
# only if
# !pip install -e .
# is active 
# then _before the PT3S Imports the currentWorkingDirectory _has to be changed to .. PT3SSourcecodeDir  
# %cd -q ..
from PT3S import Mx,Xm,Rm
# %cd -q PT3S 
# if !pip install -e . is active the cd-Change has no effect

# %% [markdown]
# # Imports

# %%
import unittest
import doctest

# %% [markdown]
# # Test Mx

# %%
# run the tests ...
unittest.TextTestRunner().run(doctest.DocTestSuite(Mx))

# %% [markdown]
# # Test Xm

# %%
# run the tests ...
unittest.TextTestRunner().run(doctest.DocTestSuite(Xm))

# %% [markdown]
# # Test Rm

# %%
# run the tests ...
unittest.TextTestRunner().run(doctest.DocTestSuite(Rm))

# %%
# ---
# Imports
# ---
import logging
logger = logging.getLogger('PT3S')  
import os
import pandas as pd
import matplotlib.pyplot as plt
path = os.path.dirname('.')

# ---
# LocalHeatingNetwork
# ---
xmlFile=os.path.join(path,'testdata\LocalHeatingNetwork.XML')
xm=Xm.Xm(xmlFile=xmlFile)
mx1File=os.path.join(path,'testdata\WDLocalHeatingNetwork\B1\V0\BZ1\M-1-0-1.MX1')
mx=Mx.Mx(mx1File=mx1File,NoH5Read=True,NoMxsRead=True)
mx.setResultsToMxsFile(NewH5Vec=True)
rm=Rm.Rm(xm=xm,mx=mx)

# %%
xm.dataFrames['vROHR'].columns

# %%
mx.mx1Df[(mx.mx1Df['isVectorChannelMx2']) & (mx.mx1Df['Sir3sID'].str.startswith('ROHR')) ]

# %%
# Prozentdarstellung - keine Klassen
plt.close('all')
fig=plt.figure()
x=rm.pltNetDHUS(timeDeltaToT= pd.to_timedelta('30 seconds')                   
                
               # ALLG
               ,pFWVBMeasureInRefPerc=True 
               ,pFWVBMeasure3Classes=False 
               
               ,pFWVBMeasureCBFixedLimits=False                
                
               # FWVB
               ,pFWVBMeasure='FWVB~*~*~*~W'
               ,pFWVBAttribute='W0LFK'
                                                                                             
               ,pFWVBAttributeRefSize=50
                
               ,pFWVBMeasureColorMap=plt.cm.autumn 
               ,pFWVBMeasureAlpha=0.9 
               ,pFWVBMeasureClip=False                  

               ,limitTopColor='palegreen'
               ,limitTopAlpha=0.9 
               ,limitTopClip=False            
               ,limitTopText='Top'                 
               
               ,limitBottomColor='violet' 
               ,limitBottomAlpha=0.9 
               ,limitBottomClip=False    
               ,limitBottomText='Bottom' 
                
               ,limitMiddleColorMap=plt.cm.autumn 
               ,limitMiddleAlpha=0.9 
               ,limitMiddleClip=False    
               ,limitMiddleText='Middle'                
  
                # CB                
                ,CBFraction=.05  
                ,CBHpad=.0275   
                ,CBLabelPad=0
                ,CBAspect=10.
                ,CBShrink=1.
                ,CBAnchorHorizontal=0.
                ,CBAnchorVertical=0.

                # ROHR
                ,pROHRMeasure='ROHR~*~*~*~QMAV'
                ,pROHRAttribute='DI'              
                
                ,pROHRClip=False
                ,pROHRAttributeLs='-' 
                ,pROHRMeasureMarker='.'

                ,pROHRAttributeColorMap=plt.cm.binary    
                ,pROHRAttríbuteColorMapUsageStart=1./3
                ,pROHRAttributeRefSize=3.               

                ,pROHRMeasureColorMap=plt.cm.cool    
                ,pROHRMeasureColorMapUsageStart=0.               
                ,pROHRMeasureRefSize=12.                        
                                                          
               )
plt.show()

# %%
# herkömmliche Darstellung
plt.close('all')
fig=plt.figure()
x=rm.pltNetDHUS(timeDeltaToT= pd.to_timedelta('30 seconds')                   
                
               # ALLG
               ,pFWVBMeasureInRefPerc=False
               ,pFWVBMeasure3Classes=False 
               
               ,pFWVBMeasureCBFixedLimits=False                
                
               # FWVB
               ,pFWVBMeasure='FWVB~*~*~*~W'
               ,pFWVBAttribute='W0LFK'
                                                                                             
               ,pFWVBAttributeRefSize=50
                
               ,pFWVBMeasureColorMap=plt.cm.autumn 
               ,pFWVBMeasureAlpha=0.9 
               ,pFWVBMeasureClip=False                  

               ,limitTopColor='palegreen'
               ,limitTopAlpha=0.9 
               ,limitTopClip=False            
               ,limitTopText='Top'                 
               
               ,limitBottomColor='violet' 
               ,limitBottomAlpha=0.9 
               ,limitBottomClip=False    
               ,limitBottomText='Bottom' 
                
               ,limitMiddleColorMap=plt.cm.autumn 
               ,limitMiddleAlpha=0.9 
               ,limitMiddleClip=False    
               ,limitMiddleText='Middle'                
  
                # CB                
                ,CBFraction=.05  
                ,CBHpad=.0275   
                ,CBLabelPad=0
                ,CBAspect=10.
                ,CBShrink=1.
                ,CBAnchorHorizontal=0.
                ,CBAnchorVertical=0.

                # ROHR
                ,pROHRMeasure='ROHR~*~*~*~QMAV'
                ,pROHRAttribute='DI'              
                
                ,pROHRClip=False
                ,pROHRAttributeLs='-' 
                ,pROHRMeasureMarker='.'

                ,pROHRAttributeColorMap=plt.cm.binary    
                ,pROHRAttríbuteColorMapUsageStart=1./3
                ,pROHRAttributeRefSize=3.               

                ,pROHRMeasureColorMap=plt.cm.cool    
                ,pROHRMeasureColorMapUsageStart=0.               
                ,pROHRMeasureRefSize=12.                        
                                                          
               )
plt.show()

# %%
plt.close('all')
fig=plt.figure(linewidth=1.)
pFWVB=rm.pltNetDHUS(
               # TIME
               timeDeltaToT= pd.to_timedelta('30 seconds')                   
                
               # ALLG
               ,pFWVBMeasureInRefPerc=True
               ,pFWVBMeasure3Classes=True 
               
               ,pFWVBMeasureCBFixedLimits=True         
               ,pFWVBMeasureCBFixedLimitLow=.659
               ,pFWVBMeasureCBFixedLimitHigh=.809
                
               # FWVB
               ,pFWVBMeasure='FWVB~*~*~*~W'
               ,pFWVBAttribute='W0LFK'
               ,pFWVBAttributeAsc=False    
               ,pFWVBGCategory=['#','BLNZ1','BLNZ1u5u7'] # ['Süd','Nord','Innenstadt','Nord PWS','NordOst BHW','Ost HWV','Ost PWF/PSE','Nord Rest'] # NAMEn von WBLZ
               ,pFWVBGCategoryXStart=.1
               ,pFWVBGCategoryYStart=.9
               ,pFWVBGCategoryYSpace=-.1               
                                                                                             
               ,pFWVBAttributeRefSize=50
                
               ,pFWVBMeasureColorMap=plt.cm.autumn 
               ,pFWVBMeasureAlpha=0.9 
               ,pFWVBMeasureClip=False                  

               ,limitTopColor='palegreen'
               ,limitTopAlpha=0.9 
               ,limitTopClip=False            
               ,limitTopText='Top'                 
               
               ,limitBottomColor='violet' 
               ,limitBottomAlpha=0.9 
               ,limitBottomClip=False    
               ,limitBottomText='Bottom' 
                
               ,limitMiddleColorMap=plt.cm.autumn 
               ,limitMiddleAlpha=0.9 
               ,limitMiddleClip=False    
               ,limitMiddleText='Middle'                
  
                # CB                
                ,CBFraction=.05  
                ,CBHpad=.0275   
                ,CBLabelPad=0
                ,CBTicklabelsHPad=-3.
                ,CBAspect=10.
                ,CBShrink=1.
                ,CBAnchorHorizontal=0.
                ,CBAnchorVertical=0.

                # ROHR
                ,pROHRMeasure='ROHR~*~*~*~QMAV'
                ,pROHRMeasureAbs=True 
                ,pROHRAttribute='DI'    
                ,pROHRAttributeAsc=False                
                
                ,pROHRClip=False
                ,pROHRAttributeLs='-' 
                ,pROHRMeasureMarker='.'

                ,pROHRAttributeColorMap=plt.cm.binary    
                ,pROHRAttríbuteColorMapUsageStart=1./3
                ,pROHRAttributeRefSize=3.               

                ,pROHRMeasureColorMap=plt.cm.cool    
                ,pROHRMeasureColorMapUsageStart=0.               
                ,pROHRMeasureRefSize=12.     

                # CB Legend (3Classes)
                ,CBLe3cTopVPad=1+1*1/4            
                ,CBLe3cMiddleVPad=.5                                                                         
                ,CBLe3cBottomVPad=0-1*1/4                  
                
                # TB      
                ,TBVSpace=0.2 
                ,TBHSpace=1.
                            
                # FIG                   
                ,pltTitle='pltNetDHUS: Klassendarstellung - Prozent '             
                ,figFrameon=True                 
                ,figEdgecolor='black' 
                ,figFacecolor='white' 
    
                # NUMANZ
                ,pFIGNrcv=['KNOT~PKON-Knoten~\S*~\S+~QM'] 
                ,pFIGNrcvXStart=.5
                ,pFIGNrcvYStart=.5
                ,pFIGNrcvYSpace=-.1    
    
                # VICs 
                ,pVICsDf=pd.DataFrame({'Kundenname': ['VIC1'],'Knotenname': ['V-K007']})
                ,pVICsXStart=.8
                ,pVICsYStart=.5
                ,pVICsYSpace=-.1    
               )
plt.show()

# %%
mx.mx1Df[mx.mx1Df['Sir3sID'].str.startswith('KNOT')]
# Out:
#     ADDEND   ATTRTYPE CLIENT_FLAGS CLIENT_ID  DATALENGTH  DATAOFFSET DATATYPE  \
# 33       0         PH            0                     4         236     REAL
# 35       0         DP            0                     4         244     REAL
# 37       0         PH            0                     4         252     REAL
# 39       0          T            0                     4         260     REAL
# 44       0          T            0                     4         280     REAL
# 50       0         QM            0                     4         304     REAL
# 93       0         DP            0                    92        1032     REAL
# 97       0          T            0                    92        1380     REAL
# 98       0         PH            0                    92        1472     REAL
# 103      0        RHO            0                     4        1732     REAL
# 104      0          P            0                     4        1736     REAL
# 105      0          H            0                     4        1740     REAL
# 106      0  HMAX_INST            0                     4        1744     REAL
# 107      0  HMIN_INST            0                     4        1748     REAL
# 108      0  PMAX_INST            0                     4        1752     REAL
# 109      0  PMIN_INST            0                     4        1756     REAL
# 110      0     PDAMPF            0                     4        1760     REAL
# 111      0        RHO            0                     4        1764     REAL
# 112      0          P            0                     4        1768     REAL
# 113      0          H            0                     4        1772     REAL
# 114      0  HMAX_INST            0                     4        1776     REAL
# 115      0  HMIN_INST            0                     4        1780     REAL
# 116      0  PMAX_INST            0                     4        1784     REAL
# 117      0  PMIN_INST            0                     4        1788     REAL
# 118      0     PDAMPF            0                     4        1792     REAL
# 119      0        RHO            0                     4        1796     REAL
# 120      0          P            0                     4        1800     REAL
# 121      0          H            0                     4        1804     REAL
# 122      0  HMAX_INST            0                     4        1808     REAL
# 123      0  HMIN_INST            0                     4        1812     REAL
# ..     ...        ...          ...       ...         ...         ...      ...
# 219      0  HMIN_INST            0                     4        2196     REAL
# 220      0  PMAX_INST            0                     4        2200     REAL
# 221      0  PMIN_INST            0                     4        2204     REAL
# 222      0     PDAMPF            0                     4        2208     REAL
# 223      0        RHO            0                     4        2212     REAL
# 224      0          P            0                     4        2216     REAL
# 225      0          H            0                     4        2220     REAL
# 226      0  HMAX_INST            0                     4        2224     REAL
# 227      0  HMIN_INST            0                     4        2228     REAL
# 228      0  PMAX_INST            0                     4        2232     REAL
# 229      0  PMIN_INST            0                     4        2236     REAL
# 230      0     PDAMPF            0                     4        2240     REAL
# 231      0        RHO            0                     4        2244     REAL
# 232      0          P            0                     4        2248     REAL
# 233      0          H            0                     4        2252     REAL
# 234      0  HMAX_INST            0                     4        2256     REAL
# 235      0  HMIN_INST            0                     4        2260     REAL
# 236      0  PMAX_INST            0                     4        2264     REAL
# 237      0  PMIN_INST            0                     4        2268     REAL
# 238      0     PDAMPF            0                     4        2272     REAL
# 239      0        RHO            0                     4        2276     REAL
# 240      0          P            0                     4        2280     REAL
# 241      0          H            0                     4        2284     REAL
# 242      0  HMAX_INST            0                     4        2288     REAL
# 243      0  HMIN_INST            0                     4        2292     REAL
# 244      0  PMAX_INST            0                     4        2296     REAL
# 245      0  PMIN_INST            0                     4        2300     REAL
# 246      0     PDAMPF            0                     4        2304     REAL
# 364      0     IAKTIV            0                    92        2968     INT4
# 371      0     WALTER            0                    92        3168     REAL
#
#      DATATYPELENGTH DEVIATION FACTOR    ...     OPCITEM_ID  \
# 33                4         0      1    ...
# 35                4         0      1    ...
# 37                4         0      1    ...
# 39                4         0      1    ...
# 44                4         0      1    ...
# 50                4         0      1    ...
# 93                4         0      1    ...
# 97                4         0      1    ...
# 98                4         0      1    ...
# 103               4         0      1    ...
# 104               4         0      1    ...
# 105               4         0      1    ...
# 106               4         0      1    ...
# 107               4         0      1    ...
# 108               4         0      1    ...
# 109               4         0      1    ...
# 110               4         0      1    ...
# 111               4         0      1    ...
# 112               4         0      1    ...
# 113               4         0      1    ...
# 114               4         0      1    ...
# 115               4         0      1    ...
# 116               4         0      1    ...
# 117               4         0      1    ...
# 118               4         0      1    ...
# 119               4         0      1    ...
# 120               4         0      1    ...
# 121               4         0      1    ...
# 122               4         0      1    ...
# 123               4         0      1    ...
# ..              ...       ...    ...    ...            ...
# 219               4         0      1    ...
# 220               4         0      1    ...
# 221               4         0      1    ...
# 222               4         0      1    ...
# 223               4         0      1    ...
# 224               4         0      1    ...
# 225               4         0      1    ...
# 226               4         0      1    ...
# 227               4         0      1    ...
# 228               4         0      1    ...
# 229               4         0      1    ...
# 230               4         0      1    ...
# 231               4         0      1    ...
# 232               4         0      1    ...
# 233               4         0      1    ...
# 234               4         0      1    ...
# 235               4         0      1    ...
# 236               4         0      1    ...
# 237               4         0      1    ...
# 238               4         0      1    ...
# 239               4         0      1    ...
# 240               4         0      1    ...
# 241               4         0      1    ...
# 242               4         0      1    ...
# 243               4         0      1    ...
# 244               4         0      1    ...
# 245               4         0      1    ...
# 246               4         0      1    ...
# 364               4         0      1    ...
# 371               4         0      1    ...
#
#                    TITLE      UNIT UPPER_LIMIT  \
# 33                           [bar]       1E+20
# 35                           [bar]       1E+20
# 37                           [bar]       1E+20
# 39                            [°C]       1E+20
# 44                            [°C]       1E+20
# 50   Externer Durchfluss     [t/h]       1E+20
# 93                        [IDPH,4]       1E+20
# 97                            [°C]       1E+20
# 98                        [IDPH,4]       1E+20
# 103                        [kg/m3]       1E+20
# 104                        [bar,a]       1E+20
# 105                       [IDPH,6]       1E+20
# 106                       [IDPH,6]       1E+20
# 107                       [IDPH,6]       1E+20
# 108                         [IDPH]       1E+20
# 109                         [IDPH]       1E+20
# 110                        [bar,a]       1E+20
# 111                        [kg/m3]       1E+20
# 112                        [bar,a]       1E+20
# 113                       [IDPH,6]       1E+20
# 114                       [IDPH,6]       1E+20
# 115                       [IDPH,6]       1E+20
# 116                         [IDPH]       1E+20
# 117                         [IDPH]       1E+20
# 118                        [bar,a]       1E+20
# 119                        [kg/m3]       1E+20
# 120                        [bar,a]       1E+20
# 121                       [IDPH,6]       1E+20
# 122                       [IDPH,6]       1E+20
# 123                       [IDPH,6]       1E+20
# ..                   ...       ...         ...
# 219                       [IDPH,6]       1E+20
# 220                         [IDPH]       1E+20
# 221                         [IDPH]       1E+20
# 222                        [bar,a]       1E+20
# 223                        [kg/m3]       1E+20
# 224                        [bar,a]       1E+20
# 225                       [IDPH,6]       1E+20
# 226                       [IDPH,6]       1E+20
# 227                       [IDPH,6]       1E+20
# 228                         [IDPH]       1E+20
# 229                         [IDPH]       1E+20
# 230                        [bar,a]       1E+20
# 231                        [kg/m3]       1E+20
# 232                        [bar,a]       1E+20
# 233                       [IDPH,6]       1E+20
# 234                       [IDPH,6]       1E+20
# 235                       [IDPH,6]       1E+20
# 236                         [IDPH]       1E+20
# 237                         [IDPH]       1E+20
# 238                        [bar,a]       1E+20
# 239                        [kg/m3]       1E+20
# 240                        [bar,a]       1E+20
# 241                       [IDPH,6]       1E+20
# 242                       [IDPH,6]       1E+20
# 243                       [IDPH,6]       1E+20
# 244                         [IDPH]       1E+20
# 245                         [IDPH]       1E+20
# 246                        [bar,a]       1E+20
# 364                             []       1E+20
# 371                            [h]       1E+20
#
#                                         Sir3sID NOfItems isVectorChannel  \
# 33             KNOT~V-L~~5736262931552588702~PH        1           False
# 35          KNOT~V-K007~~5741235692335544560~DP        1           False
# 37             KNOT~R-L~~5356267303828212700~PH        1           False
# 39              KNOT~V-1~~5049461676240771430~T        1           False
# 44               KNOT~R3~~5219230031772497417~T        1           False
# 50     KNOT~PKON-Knoten~~5397990465339071638~QM        1           False
# 93                                 KNOT~*~~*~DP       23            True
# 97                                  KNOT~*~~*~T       23            True
# 98                                 KNOT~*~~*~PH       23            True
# 103           KNOT~V-L~~5736262931552588702~RHO        1           False
# 104             KNOT~V-L~~5736262931552588702~P        1           False
# 105             KNOT~V-L~~5736262931552588702~H        1           False
# 106     KNOT~V-L~~5736262931552588702~HMAX_INST        1           False
# 107     KNOT~V-L~~5736262931552588702~HMIN_INST        1           False
# 108     KNOT~V-L~~5736262931552588702~PMAX_INST        1           False
# 109     KNOT~V-L~~5736262931552588702~PMIN_INST        1           False
# 110        KNOT~V-L~~5736262931552588702~PDAMPF        1           False
# 111        KNOT~V-K000~~4766681917240867943~RHO        1           False
# 112          KNOT~V-K000~~4766681917240867943~P        1           False
# 113          KNOT~V-K000~~4766681917240867943~H        1           False
# 114  KNOT~V-K000~~4766681917240867943~HMAX_INST        1           False
# 115  KNOT~V-K000~~4766681917240867943~HMIN_INST        1           False
# 116  KNOT~V-K000~~4766681917240867943~PMAX_INST        1           False
# 117  KNOT~V-K000~~4766681917240867943~PMIN_INST        1           False
# 118     KNOT~V-K000~~4766681917240867943~PDAMPF        1           False
# 119        KNOT~V-K001~~4756962427318766791~RHO        1           False
# 120          KNOT~V-K001~~4756962427318766791~P        1           False
# 121          KNOT~V-K001~~4756962427318766791~H        1           False
# 122  KNOT~V-K001~~4756962427318766791~HMAX_INST        1           False
# 123  KNOT~V-K001~~4756962427318766791~HMIN_INST        1           False
# ..                                          ...      ...             ...
# 219  KNOT~R-K004~~4638663808856251977~HMIN_INST        1           False
# 220  KNOT~R-K004~~4638663808856251977~PMAX_INST        1           False
# 221  KNOT~R-K004~~4638663808856251977~PMIN_INST        1           False
# 222     KNOT~R-K004~~4638663808856251977~PDAMPF        1           False
# 223        KNOT~R-K005~~5183147862966701025~RHO        1           False
# 224          KNOT~R-K005~~5183147862966701025~P        1           False
# 225          KNOT~R-K005~~5183147862966701025~H        1           False
# 226  KNOT~R-K005~~5183147862966701025~HMAX_INST        1           False
# 227  KNOT~R-K005~~5183147862966701025~HMIN_INST        1           False
# 228  KNOT~R-K005~~5183147862966701025~PMAX_INST        1           False
# 229  KNOT~R-K005~~5183147862966701025~PMIN_INST        1           False
# 230     KNOT~R-K005~~5183147862966701025~PDAMPF        1           False
# 231        KNOT~R-K006~~5543326527366090679~RHO        1           False
# 232          KNOT~R-K006~~5543326527366090679~P        1           False
# 233          KNOT~R-K006~~5543326527366090679~H        1           False
# 234  KNOT~R-K006~~5543326527366090679~HMAX_INST        1           False
# 235  KNOT~R-K006~~5543326527366090679~HMIN_INST        1           False
# 236  KNOT~R-K006~~5543326527366090679~PMAX_INST        1           False
# 237  KNOT~R-K006~~5543326527366090679~PMIN_INST        1           False
# 238     KNOT~R-K006~~5543326527366090679~PDAMPF        1           False
# 239        KNOT~R-K007~~5508992300317633799~RHO        1           False
# 240          KNOT~R-K007~~5508992300317633799~P        1           False
# 241          KNOT~R-K007~~5508992300317633799~H        1           False
# 242  KNOT~R-K007~~5508992300317633799~HMAX_INST        1           False
# 243  KNOT~R-K007~~5508992300317633799~HMIN_INST        1           False
# 244  KNOT~R-K007~~5508992300317633799~PMAX_INST        1           False
# 245  KNOT~R-K007~~5508992300317633799~PMIN_INST        1           False
# 246     KNOT~R-K007~~5508992300317633799~PDAMPF        1           False
# 364                            KNOT~*~~*~IAKTIV       23            True
# 371                            KNOT~*~~*~WALTER       23            True
#
#     isVectorChannelMx2 isVectorChannelMx2Rvec unpackIdx
# 33               False                  False        33
# 35               False                  False        35
# 37               False                  False        37
# 39               False                  False        39
# 44               False                  False        44
# 50               False                  False        50
# 93                True                  False       232
# 97                True                  False       319
# 98                True                  False       342
# 103              False                  False       407
# 104              False                  False       408
# 105              False                  False       409
# 106              False                  False       410
# 107              False                  False       411
# 108              False                  False       412
# 109              False                  False       413
# 110              False                  False       414
# 111              False                  False       415
# 112              False                  False       416
# 113              False                  False       417
# 114              False                  False       418
# 115              False                  False       419
# 116              False                  False       420
# 117              False                  False       421
# 118              False                  False       422
# 119              False                  False       423
# 120              False                  False       424
# 121              False                  False       425
# 122              False                  False       426
# 123              False                  False       427
# ..                 ...                    ...       ...
# 219              False                  False       523
# 220              False                  False       524
# 221              False                  False       525
# 222              False                  False       526
# 223              False                  False       527
# 224              False                  False       528
# 225              False                  False       529
# 226              False                  False       530
# 227              False                  False       531
# 228              False                  False       532
# 229              False                  False       533
# 230              False                  False       534
# 231              False                  False       535
# 232              False                  False       536
# 233              False                  False       537
# 234              False                  False       538
# 235              False                  False       539
# 236              False                  False       540
# 237              False                  False       541
# 238              False                  False       542
# 239              False                  False       543
# 240              False                  False       544
# 241              False                  False       545
# 242              False                  False       546
# 243              False                  False       547
# 244              False                  False       548
# 245              False                  False       549
# 246              False                  False       550
# 364               True                  False       716
# 371               True                  False       766
#
# [155 rows x 28 columns]

# %%
df=pd.DataFrame(
{
 'Kundenname': ['VIC1']
,'Knotenname': ['V-K007']
}
)

# %%
df
# Out:
#   Knotenname Kundenname
# 0        xxx       VIC1

# %%
mx.mx1Df.columns
# Out:
# Index(['ADDEND', 'ATTRTYPE', 'CLIENT_FLAGS', 'CLIENT_ID', 'DATALENGTH',
#        'DATAOFFSET', 'DATATYPE', 'DATATYPELENGTH', 'DEVIATION', 'FACTOR',
#        'FLAGS', 'LINKED_CHANNEL', 'LOWER_LIMIT', 'NAME1', 'NAME2', 'NAME3',
#        'OBJTYPE', 'OBJTYPE_PK', 'OPCITEM_ID', 'TITLE', 'UNIT', 'UPPER_LIMIT',
#        'Sir3sID', 'NOfItems', 'isVectorChannel', 'isVectorChannelMx2',
#        'isVectorChannelMx2Rvec', 'unpackIdx'],
#       dtype='object')

# %%
vNRCV_Mx1=xm.dataFrames['vNRCV_Mx1']
vNRCV_Mx1.columns
# Out:
# Index(['Sir3sID', 'cRefLfdNr', 'CONT', 'CONT_ID', 'CONT_LFDNR', 'DPGR',
#        'OBJTYPE', 'fkOBJTYPE', 'ATTRTYPE', 'pk_ROWS', 'tk_ROWS', 'pk', 'tk',
#        'pXYLB'],
#       dtype='object')

# %%
#vNRCV_Mx1=vNRCV_Mx1.assign(Sir3sIDLfdNr=vNRCV_Mx1.sort_values(['Sir3sID','OBJTYPE','OBJID']).groupby(['LFDNR']).cumcount()+1)


#.assign(nrObjInGroup=vLAYR.sort_values(['LFDNR','OBJTYPE','OBJID']).groupby(['LFDNR']).cumcount()+1)

# %%
vNRCV_Mx1_g=vNRCV_Mx1.groupby(['Sir3sID']).size()

# %%
vNRCV_Mx1_Sir3sIDs=pd.DataFrame(vNRCV_Mx1_g.index)

# %%
vNRCV_Mx1_Sir3sIDs
# Out:
#                                          Sir3sID
# 0              FWES~R3~V-1~5638756766880678918~W
# 1       KNOT~PKON-Knoten~~5397990465339071638~QM
# 2               KNOT~R-L~~5356267303828212700~PH
# 3                 KNOT~R3~~5219230031772497417~T
# 4                KNOT~V-1~~5049461676240771430~T
# 5            KNOT~V-K007~~5741235692335544560~DP
# 6               KNOT~V-L~~5736262931552588702~PH
# 7              PUMP~R-1~R2~5481331875203087055~N
# 8            VENT~V-1~V-L~4678923650983295610~QM
# 9        WBLZ~BLNZ1u5u7~~4694700216019268978~WVB
# 10    WBLZ~WärmeblnzGes~~5262603207038486299~WES
# 11  WBLZ~WärmeblnzGes~~5262603207038486299~WSPEI
# 12    WBLZ~WärmeblnzGes~~5262603207038486299~WVB
# 13  WBLZ~WärmeblnzGes~~5262603207038486299~WVERL

# %%
pFWVB.columns
# Out:
# Index(['BESCHREIBUNG', 'IDREFERENZ', 'W0', 'LFK', 'W0LFK', 'TVL0', 'TRS0',
#        'LFKT', 'W', 'W_min', 'W_max', 'INDTR', 'TRSK', 'VTYP', 'DPHAUS',
#        'IMBG', 'IRFV', 'pk', 'tk', 'NAME_i', 'KVR_i', 'TM_i', 'XKOR_i',
#        'YKOR_i', 'ZKOR_i', 'pXCor_i', 'pYCor_i', 'NAME_k', 'KVR_k', 'TM_k',
#        'XKOR_k', 'YKOR_k', 'ZKOR_k', 'pXCor_k', 'pYCor_k', 'CONT', 'CONT_ID',
#        'CONT_LFDNR', 'WBLZ', 'Measure', 'MCategory', 'GCategory'],
#       dtype='object')

# %%
vKNOT=xm.dataFrames['vKNOT']
vWBLZ=xm.dataFrames['vWBLZ']
vWBLZ_vKNOT=pd.merge(vWBLZ,vKNOT,left_on='OBJID',right_on='pk')
vWBLZ_vKNOT_pFWVB=pd.merge(vWBLZ_vKNOT,pFWVB,left_on='NAME_y',right_on='NAME_i')
vWBLZ_vKNOT_pFWVB.columns
# Out:
# Index(['AKTIV', 'BESCHREIBUNG_x', 'IDIM', 'NAME_x', 'OBJID', 'OBJTYPE', 'pk_x',
#        'NAME_y', 'BESCHREIBUNG_y', 'IDREFERENZ_x', 'CONT_x', 'CONT_ID_x',
#        'CONT_LFDNR_x', 'CONT_VKNO', 'KTYP', 'LFAKT', 'QM_EIN', 'QVAR_NAME',
#        'QM', 'QM_min', 'QM_max', 'KVR', 'TE', 'TM', 'XKOR', 'YKOR', 'ZKOR',
#        'pk_y', 'tk_x', 'pXCor', 'pYCor', 'BESCHREIBUNG', 'IDREFERENZ_y', 'W0',
#        'LFK', 'W0LFK', 'TVL0', 'TRS0', 'LFKT', 'W', 'W_min', 'W_max', 'INDTR',
#        'TRSK', 'VTYP', 'DPHAUS', 'IMBG', 'IRFV', 'pk', 'tk_y', 'NAME_i',
#        'KVR_i', 'TM_i', 'XKOR_i', 'YKOR_i', 'ZKOR_i', 'pXCor_i', 'pYCor_i',
#        'NAME_k', 'KVR_k', 'TM_k', 'XKOR_k', 'YKOR_k', 'ZKOR_k', 'pXCor_k',
#        'pYCor_k', 'CONT_y', 'CONT_ID_y', 'CONT_LFDNR_y', 'WBLZ', 'Measure',
#        'MCategory', 'GCategory'],
#       dtype='object')

# %%
vWBLZ_vKNOT_pFWVB=vWBLZ_vKNOT_pFWVB[['NAME_x','NAME_i','pk','W','pk_x','WBLZ', 'Measure','MCategory', 'GCategory']]
vWBLZ_vKNOT_pFWVB.rename(columns={'NAME_x':'NAME','pk_x':'pkWBLZ'},inplace=True)
vWBLZ_vKNOT_pFWVB
# Out:
#         NAME  NAME_i                   pk      W               pkWBLZ  \
# 0      BLNZ1  V-K002  4643800032883366034  160.0  5579937562601803472
# 1    BLNZ1u5  V-K002  4643800032883366034  160.0  5187647097142898375
# 2  BLNZ1u5u7  V-K002  4643800032883366034  160.0  4694700216019268978
# 3      BLNZ5  V-K005  5121101823283893406  160.0  5581152085151655438
# 4    BLNZ1u5  V-K005  5121101823283893406  160.0  5187647097142898375
# 5  BLNZ1u5u7  V-K005  5121101823283893406  160.0  4694700216019268978
# 6  BLNZ1u5u7  V-K007  5400405917816384862  160.0  4694700216019268978
#
#                           WBLZ   Measure MCategory               GCategory
# 0  [BLNZ1, BLNZ1u5, BLNZ1u5u7]  0.809706       Top  {'BLNZ1', 'BLNZ1u5u7'}
# 1  [BLNZ1, BLNZ1u5, BLNZ1u5u7]  0.809706       Top  {'BLNZ1', 'BLNZ1u5u7'}
# 2  [BLNZ1, BLNZ1u5, BLNZ1u5u7]  0.809706       Top  {'BLNZ1', 'BLNZ1u5u7'}
# 3  [BLNZ1u5, BLNZ1u5u7, BLNZ5]  0.660432    Middle               BLNZ1u5u7
# 4  [BLNZ1u5, BLNZ1u5u7, BLNZ5]  0.660432    Middle               BLNZ1u5u7
# 5  [BLNZ1u5, BLNZ1u5u7, BLNZ5]  0.660432    Middle               BLNZ1u5u7
# 6                  [BLNZ1u5u7]  0.655515    Bottom               BLNZ1u5u7

# %%
vWBLZ_vKNOT_pFWVB_vNRCV_Mx1=pd.merge(vWBLZ_vKNOT_pFWVB,vNRCV_Mx1,left_on='pkWBLZ',right_on='fkOBJTYPE',how='left')
vWBLZ_vKNOT_pFWVB_vNRCV_Mx1.columns
# Out:
# Index(['NAME', 'NAME_i', 'pk_x', 'W', 'pkWBLZ', 'WBLZ', 'Measure', 'MCategory',
#        'GCategory', 'Sir3sID', 'cRefLfdNr', 'CONT', 'CONT_ID', 'CONT_LFDNR',
#        'DPGR', 'OBJTYPE', 'fkOBJTYPE', 'ATTRTYPE', 'pk_ROWS', 'tk_ROWS',
#        'pk_y', 'tk', 'pXYLB'],
#       dtype='object')

# %%
#vWBLZ_vKNOT_pFWVB_vNRCV_Mx1=vWBLZ_vKNOT_pFWVB_vNRCV_Mx1.drop_duplicates()
vWBLZ_vKNOT_pFWVB_vNRCV_Mx1['Sir3sID']=vWBLZ_vKNOT_pFWVB_vNRCV_Mx1['Sir3sID'].fillna(value='')
vWBLZ_vKNOT_pFWVB_vNRCV_Mx1['cRefLfdNr']=vWBLZ_vKNOT_pFWVB_vNRCV_Mx1['cRefLfdNr'].fillna(value=1)
vWBLZ_vKNOT_pFWVB_vNRCV_Mx1.rename(columns={'pk_x':'pkFWVB'},inplace=True)
vWBLZ_vKNOT_pFWVB_vNRCV_Mx1.columns
# Out:
# Index(['NAME', 'NAME_i', 'pkFWVB', 'W', 'pkWBLZ', 'WBLZ', 'Measure',
#        'MCategory', 'GCategory', 'Sir3sID', 'cRefLfdNr', 'CONT', 'CONT_ID',
#        'CONT_LFDNR', 'DPGR', 'OBJTYPE', 'fkOBJTYPE', 'ATTRTYPE', 'pk_ROWS',
#        'tk_ROWS', 'pk_y', 'tk', 'pXYLB'],
#       dtype='object')

# %%
vWBLZ_vKNOT_pFWVB_vNRCV_Mx1=vWBLZ_vKNOT_pFWVB_vNRCV_Mx1[['NAME','NAME_i','pkFWVB','W','WBLZ','Sir3sID'
                                                         , 'Measure','MCategory', 'GCategory','cRefLfdNr']]

# %%
vWBLZ_vKNOT_pFWVB_vNRCV_Mx1
# Out:
#         NAME  NAME_i               pkFWVB      W                         WBLZ  \
# 0      BLNZ1  V-K002  4643800032883366034  160.0  [BLNZ1, BLNZ1u5, BLNZ1u5u7]
# 1    BLNZ1u5  V-K002  4643800032883366034  160.0  [BLNZ1, BLNZ1u5, BLNZ1u5u7]
# 2  BLNZ1u5u7  V-K002  4643800032883366034  160.0  [BLNZ1, BLNZ1u5, BLNZ1u5u7]
# 3      BLNZ5  V-K005  5121101823283893406  160.0  [BLNZ1u5, BLNZ1u5u7, BLNZ5]
# 4    BLNZ1u5  V-K005  5121101823283893406  160.0  [BLNZ1u5, BLNZ1u5u7, BLNZ5]
# 5  BLNZ1u5u7  V-K005  5121101823283893406  160.0  [BLNZ1u5, BLNZ1u5u7, BLNZ5]
# 6  BLNZ1u5u7  V-K007  5400405917816384862  160.0                  [BLNZ1u5u7]
#
#                                    Sir3sID   Measure MCategory  \
# 0                                           0.809706       Top
# 1                                           0.809706       Top
# 2  WBLZ~BLNZ1u5u7~~4694700216019268978~WVB  0.809706       Top
# 3                                           0.660432    Middle
# 4                                           0.660432    Middle
# 5  WBLZ~BLNZ1u5u7~~4694700216019268978~WVB  0.660432    Middle
# 6  WBLZ~BLNZ1u5u7~~4694700216019268978~WVB  0.655515    Bottom
#
#                 GCategory  cRefLfdNr
# 0  {'BLNZ1', 'BLNZ1u5u7'}          1
# 1  {'BLNZ1', 'BLNZ1u5u7'}          1
# 2  {'BLNZ1', 'BLNZ1u5u7'}          1
# 3               BLNZ1u5u7          1
# 4               BLNZ1u5u7          1
# 5               BLNZ1u5u7          1
# 6               BLNZ1u5u7          1

# %%
vWBLZ_vKNOT_pFWVB_vNRCV_Mx1=vWBLZ_vKNOT_pFWVB_vNRCV_Mx1[vWBLZ_vKNOT_pFWVB_vNRCV_Mx1['cRefLfdNr']==1]

# %%
vWBLZ_vKNOT_pFWVB_vNRCV_Mx1.drop('cRefLfdNr',axis=1,inplace=True)

# %%
vWBLZ_vKNOT_pFWVB_vNRCV_Mx1.sort_values(['NAME','MCategory','NAME_i'])
# Out:
#         NAME  NAME_i               pkFWVB      W                         WBLZ  \
# 0      BLNZ1  V-K002  4643800032883366034  160.0  [BLNZ1, BLNZ1u5, BLNZ1u5u7]
# 4    BLNZ1u5  V-K005  5121101823283893406  160.0  [BLNZ1u5, BLNZ1u5u7, BLNZ5]
# 1    BLNZ1u5  V-K002  4643800032883366034  160.0  [BLNZ1, BLNZ1u5, BLNZ1u5u7]
# 6  BLNZ1u5u7  V-K007  5400405917816384862  160.0                  [BLNZ1u5u7]
# 5  BLNZ1u5u7  V-K005  5121101823283893406  160.0  [BLNZ1u5, BLNZ1u5u7, BLNZ5]
# 2  BLNZ1u5u7  V-K002  4643800032883366034  160.0  [BLNZ1, BLNZ1u5, BLNZ1u5u7]
# 3      BLNZ5  V-K005  5121101823283893406  160.0  [BLNZ1u5, BLNZ1u5u7, BLNZ5]
#
#                                    Sir3sID   Measure MCategory  \
# 0                                           0.809706       Top
# 4                                           0.660432    Middle
# 1                                           0.809706       Top
# 6  WBLZ~BLNZ1u5u7~~4694700216019268978~WVB  0.655515    Bottom
# 5  WBLZ~BLNZ1u5u7~~4694700216019268978~WVB  0.660432    Middle
# 2  WBLZ~BLNZ1u5u7~~4694700216019268978~WVB  0.809706       Top
# 3                                           0.660432    Middle
#
#                 GCategory
# 0  {'BLNZ1', 'BLNZ1u5u7'}
# 4               BLNZ1u5u7
# 1  {'BLNZ1', 'BLNZ1u5u7'}
# 6               BLNZ1u5u7
# 5               BLNZ1u5u7
# 2  {'BLNZ1', 'BLNZ1u5u7'}
# 3               BLNZ1u5u7

# %%
vWBLZ_vKNOT_pFWVB_vNRCV_Mx1['WIst']=vWBLZ_vKNOT_pFWVB_vNRCV_Mx1.apply(lambda row: row.Measure    * row.W   , axis=1)
#.sort_values(['NAME','MCategory','NAME_i'])
#vFWVB.apply(lambda row: row.LFK    * row.W0   , axis=1)
vWBLZ_vKNOT_pFWVB_vNRCV_Mx1
# Out:
#         NAME  NAME_i               pkFWVB      W                         WBLZ  \
# 0      BLNZ1  V-K002  4643800032883366034  160.0  [BLNZ1, BLNZ1u5, BLNZ1u5u7]
# 1    BLNZ1u5  V-K002  4643800032883366034  160.0  [BLNZ1, BLNZ1u5, BLNZ1u5u7]
# 2  BLNZ1u5u7  V-K002  4643800032883366034  160.0  [BLNZ1, BLNZ1u5, BLNZ1u5u7]
# 3      BLNZ5  V-K005  5121101823283893406  160.0  [BLNZ1u5, BLNZ1u5u7, BLNZ5]
# 4    BLNZ1u5  V-K005  5121101823283893406  160.0  [BLNZ1u5, BLNZ1u5u7, BLNZ5]
# 5  BLNZ1u5u7  V-K005  5121101823283893406  160.0  [BLNZ1u5, BLNZ1u5u7, BLNZ5]
# 6  BLNZ1u5u7  V-K007  5400405917816384862  160.0                  [BLNZ1u5u7]
#
#                                    Sir3sID   Measure MCategory  \
# 0                                           0.809706       Top
# 1                                           0.809706       Top
# 2  WBLZ~BLNZ1u5u7~~4694700216019268978~WVB  0.809706       Top
# 3                                           0.660432    Middle
# 4                                           0.660432    Middle
# 5  WBLZ~BLNZ1u5u7~~4694700216019268978~WVB  0.660432    Middle
# 6  WBLZ~BLNZ1u5u7~~4694700216019268978~WVB  0.655515    Bottom
#
#                 GCategory        WIst
# 0  {'BLNZ1', 'BLNZ1u5u7'}  129.553030
# 1  {'BLNZ1', 'BLNZ1u5u7'}  129.553030
# 2  {'BLNZ1', 'BLNZ1u5u7'}  129.553030
# 3               BLNZ1u5u7  105.669144
# 4               BLNZ1u5u7  105.669144
# 5               BLNZ1u5u7  105.669144
# 6               BLNZ1u5u7  104.882339

# %%
vAggNumAnz=vWBLZ_vKNOT_pFWVB_vNRCV_Mx1.groupby(['NAME','Sir3sID']).size()

# %%
vAggNumAnz
# Out:
# NAME       Sir3sID
# BLNZ1                                                 1
# BLNZ1u5                                               2
# BLNZ1u5u7  WBLZ~BLNZ1u5u7~~4694700216019268978~WVB    3
# BLNZ5                                                 1
# dtype: int64

# %%
vAggNumAnz.loc['BLNZ1u5u7'].index[0]#['Sir3sID']
# Out:
# 'WBLZ~BLNZ1u5u7~~4694700216019268978~WVB'

# %%
#import numpy as np
y=vWBLZ_vKNOT_pFWVB_vNRCV_Mx1.groupby(['NAME','MCategory']).agg(
    {
        'W': ['size','min', 'max', 'sum']
       ,'Measure': ['size','min', 'max', 'sum']
       ,'WIst': ['size','min', 'max', 'sum']
    })


#([np.size, np.cumsum])

# %%
y
# Out:
#                     Measure                               WIst              \
#                        size       min       max       sum size         min
# NAME      MCategory
# BLNZ1     Top             1  0.809706  0.809706  0.809706    1  129.553030
# BLNZ1u5   Middle          1  0.660432  0.660432  0.660432    1  105.669144
#           Top             1  0.809706  0.809706  0.809706    1  129.553030
# BLNZ1u5u7 Bottom          1  0.655515  0.655515  0.655515    1  104.882339
#           Middle          1  0.660432  0.660432  0.660432    1  105.669144
#           Top             1  0.809706  0.809706  0.809706    1  129.553030
# BLNZ5     Middle          1  0.660432  0.660432  0.660432    1  105.669144
#
#                                                W
#                             max         sum size    min    max    sum
# NAME      MCategory
# BLNZ1     Top        129.553030  129.553030    1  160.0  160.0  160.0
# BLNZ1u5   Middle     105.669144  105.669144    1  160.0  160.0  160.0
#           Top        129.553030  129.553030    1  160.0  160.0  160.0
# BLNZ1u5u7 Bottom     104.882339  104.882339    1  160.0  160.0  160.0
#           Middle     105.669144  105.669144    1  160.0  160.0  160.0
#           Top        129.553030  129.553030    1  160.0  160.0  160.0
# BLNZ5     Middle     105.669144  105.669144    1  160.0  160.0  160.0

# %%
y.loc['BLNZ1','Top']['Measure']['size']
# Out:
# 1.0

# %%
x=vWBLZ_vKNOT_pFWVB_vNRCV_Mx1.groupby(['NAME']).agg(
    {
        'W': ['size','min', 'max', 'sum']
       ,'Measure': ['size','min', 'max', 'sum']
       ,'WIst': ['size','min', 'max', 'sum']
    })

# %%
x
# Out:
#           WIst                                        W                       \
#           size         min         max         sum size    min    max    sum
# NAME
# BLNZ1        1  129.553030  129.553030  129.553030    1  160.0  160.0  160.0
# BLNZ1u5      2  105.669144  129.553030  235.222174    2  160.0  160.0  320.0
# BLNZ1u5u7    3  104.882339  129.553030  340.104513    3  160.0  160.0  480.0
# BLNZ5        1  105.669144  105.669144  105.669144    1  160.0  160.0  160.0
#
#           Measure
#              size       min       max       sum
# NAME
# BLNZ1           1  0.809706  0.809706  0.809706
# BLNZ1u5         2  0.660432  0.809706  1.470139
# BLNZ1u5u7       3  0.655515  0.809706  2.125653
# BLNZ5           1  0.660432  0.660432  0.660432

# %%
x.loc['BLNZ1u5u7']['WIst']['sum']
# Out:
# 340.1045132535877

# %%
x.loc['BLNxZ1u5u7']['WIst']['sum']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\Wolters\Anaconda3\lib\site-packages\pandas\core\indexing.py in _has_valid_type(self, key, axis)
#    1394                 if key not in ax:
# -> 1395                     error()
#    1396             except TypeError as e:
#
# C:\Users\Wolters\Anaconda3\lib\site-packages\pandas\core\indexing.py in error()
#    1389                 raise KeyError("the label [%s] is not in the [%s]" %
# -> 1390                                (key, self.obj._get_axis_name(axis)))
#    1391
#
# KeyError: 'the label [BLNxZ1u5u7] is not in the [index]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-76-6e1e7eb8e77d> in <module>()
# ----> 1 x.loc['BLNxZ1u5u7']['WIst']['sum']
#
# C:\Users\Wolters\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1294             return self._getitem_tuple(key)
#    1295         else:
# -> 1296             return self._getitem_axis(key, axis=0)
#    1297
#    1298     def _getitem_axis(self, key, axis=0):
#
# C:\Users\Wolters\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1464
#    1465         # fall thru to straight lookup
# -> 1466         self._has_valid_type(key, axis)
#    1467         return self._get_label(key, axis=axis)
#    1468
#
# C:\Users\Wolters\Anaconda3\lib\site-packages\pandas\core\indexing.py in _has_valid_type(self, key, axis)
#    1401                 raise
#    1402             except:
# -> 1403                 error()
#    1404
#    1405         return True
#
# C:\Users\Wolters\Anaconda3\lib\site-packages\pandas\core\indexing.py in error()
#    1388                                     "key")
#    1389                 raise KeyError("the label [%s] is not in the [%s]" %
# -> 1390                                (key, self.obj._get_axis_name(axis)))
#    1391
#    1392             try:
#
# KeyError: 'the label [BLNxZ1u5u7] is not in the [index]'

# %%
mx.mx1Df.columns
# Out:
# Index(['ADDEND', 'ATTRTYPE', 'CLIENT_FLAGS', 'CLIENT_ID', 'DATALENGTH',
#        'DATAOFFSET', 'DATATYPE', 'DATATYPELENGTH', 'DEVIATION', 'FACTOR',
#        'FLAGS', 'LINKED_CHANNEL', 'LOWER_LIMIT', 'NAME1', 'NAME2', 'NAME3',
#        'OBJTYPE', 'OBJTYPE_PK', 'OPCITEM_ID', 'TITLE', 'UNIT', 'UPPER_LIMIT',
#        'Sir3sID', 'NOfItems', 'isVectorChannel', 'isVectorChannelMx2',
#        'isVectorChannelMx2Rvec', 'unpackIdx'],
#       dtype='object')

# %% [markdown]
# # Deploy
#
# python setup.py clean sdist bdist_wheel
#
# pip install twine
#
# twine upload dist/*

# %% [markdown]
# # Develop

# %%
# !pip install -e .

# %% [markdown]
# due to ...\Lib\site-packages\PT3S.egg-link
#
# import PT3S
#
# will work (if PythonShell is executed .. PT3SSourcecodeDir)
#
# and point to _local PT3SSourcecodeDir

# %% [markdown]
# Repository: https://github.com/aw3s/PT3S.git
