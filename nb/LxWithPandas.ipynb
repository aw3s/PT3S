# %% [markdown]
# # LxWithPandas

# %%
import Lx

# %%
#%pwd
#%dhist
#0: PT3S\nb (notebooks ipynbDir)
#%cd -0
#%cd .. 
# notebooks workingDir should be PT3S
# %cd ..
# Out:
# C:\Users\Wolters\Source\Repos\PT3S

# %%
logFile='./testdata/20171103__000001.log'

# %%
lx=Lx.LxSirOPC(logFile=logFile)

# %% [markdown]
# # pandas

# %%
import pandas as pd

# %% [markdown]
# ## Excel

# %%
lx.pdf.to_excel('./testresults/20171103__000001.xlsx', sheet_name='Sheet1')

# %% [markdown]
# # SIR 3S Processdata Import File

# %%
df=lx.getProcessDataToSirCalc()
df = df.rename(columns={'TableName':'NAME','ProcessDay':'TAG','ProcessTime':'UHRZEIT','Value':'WERT','TimeNr':'ZEITKANAL'})

# %%
#df.to_csv('./testresults/20171103__000001_TABL.csv',sep=';',index=False,columns=['TableName','ProcessDay','ProcessTime','Value','TimeNr'])
df.to_csv('./testresults/20171103__000001_TABL.csv',sep=';',index=False,columns=['NAME','TAG','UHRZEIT','WERT','ZEITKANAL'])
